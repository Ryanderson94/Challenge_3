# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
# Import required libraries to be later used in the program
import pandas as pd
from pathlib import Path
import warnings
# %matplotlib inline

# %%
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Import the bitstamp.csv into the report to be analyzed, create a dataframe and use the Timestamp column as the index
bitstamp = pd.read_csv(
    Path("./Resources/bitstamp.csv"),
    index_col="Timestamp",
    parse_dates=True,
    infer_datetime_format=True
)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
display(bitstamp.head())
display(bitstamp.tail())
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# ...

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Import the coinbase.csv into the report to be analyzed, create a dataframe and use the Timestamp column as the index
coinbase = pd.read_csv(
    Path("./Resources/coinbase.csv"),
    index_col="Timestamp",
    parse_dates=True,
    infer_datetime_format=True
)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
display(coinbase.head())
display(coinbase.tail())
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# ...

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# Drop all NaN values from the bitstamp dataframe
bitstamp = bitstamp.dropna()

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Remove special characters from the Close column so we can convert to a float for analysis
bitstamp['Close'] = bitstamp['Close'].str.replace("$","")
bitstamp.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
bitstamp['Close'] = pd.to_numeric(bitstamp['Close'])
bitstamp.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00  13620.00    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Check for duplicates - if present remove the rows from dataframe
bitstamp.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Drop all NaN values from the coinbase dataframe
coinbase = coinbase.dropna()

# %%
# Remove special characters from the Close column so we can convert to a float for analysis
coinbase['Close'] = coinbase['Close'].str.replace("$","")
coinbase.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
# Convert the Close data type to a float
coinbase['Close'] = pd.to_numeric(coinbase['Close'])
coinbase.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00  13580.00   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
# Check for duplicates - if present remove the rows from dataframe
coinbase.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Pare down the bitstamp dataframe to just the index (Timestamp) and Close columns 
bitstamp_sliced = bitstamp.loc[:,'Close']

# Review the first five rows of the DataFrame to ensure correct manipulation
pd.DataFrame(bitstamp_sliced.head())
# Out:
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13646.48
# 2018-01-01 00:01:00  13658.75
# 2018-01-01 00:02:00  13610.22
# 2018-01-01 00:03:00  13639.09
# 2018-01-01 00:04:00  13620.00

# %%
# Pare down the coinbase dataframe to just the index (Timestamp) and Close columns 
coinbase_sliced = coinbase.loc[:,'Close']

# Review the first five rows of the DataFrame to ensure correct manipulation
pd.DataFrame(coinbase_sliced.head())
# Out:
#                         Close
# Timestamp
# 2018-01-01 00:00:00  13608.49
# 2018-01-01 00:01:00  13601.66
# 2018-01-01 00:02:00  13580.00
# 2018-01-01 00:03:00  13550.34
# 2018-01-01 00:04:00  13583.44

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
bitstamp_sliced.describe()
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the coinbase DataFrame
coinbase_sliced.describe()
# Out:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close, dtype: float64

# %%
# Generate Bitstamp visualization to illustate Close prices across the entire dataset 
bitstamp_sliced.plot(figsize=(14,6) , title='Bitstamp Prices')
# Out:
# <AxesSubplot:title={'center':'Bitstamp Prices'}, xlabel='Timestamp'>

# %%
# Generate Coinbase visualization to illustate Close prices across the entire dataset 
coinbase_sliced.plot(figsize=(14,6) , title='Coinbase Prices')
# Out:
# <AxesSubplot:title={'center':'Coinbase Prices'}, xlabel='Timestamp'>

# %%
# Generate a visualization to illustate Coinbase and Bitstamp prices over the entire dataset within the same figure
ax = bitstamp_sliced.plot(figsize=(20,10), title='Bitstamp v Coinbase Prices', color='orange')

coinbase_sliced.plot(figsize=(20,10), color='blue', ax=ax)

ax.legend(["Bitstamp","Coinbase"])

# %%
# Generate a visualization to illustate Coinbase and Bitstamp prices over the month of January within the same figure
ax = bitstamp_sliced.loc["2018-01-01":"2018-01-31"].plot(figsize=(20,10),title='Bitstamp v Coinbase Prices January 2018', color='orange')

coinbase_sliced.loc["2018-01-01":"2018-01-31"].plot(color='blue',ax=ax)

ax.legend(["Bitstamp","Coinbase"])

# %%
# Generate a visualization to illustate Coinbase and Bitstamp prices over the month of March within the same figure
ax = bitstamp_sliced.loc["2018-03-01":"2018-03-31"].plot(figsize=(20,10),title='Bitstamp v Coinbase Prices March 2018', color='orange')

coinbase_sliced.loc["2018-03-01":"2018-03-31"].plot(color='blue',ax=ax)

ax.legend(["Bitstamp","Coinbase"])

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread changed as time progressed?
#
# **Answer** Based on the visualizations it appears that the degree of spread has decreased from the first month analyzed (January) to the second month analyzed (February).

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Generate a visualization to illustate Coinbase and Bitstamp prices over the course of one day (January 4th) within the same figure
ax = bitstamp_sliced.loc["2018-01-04":"2018-01-4"].plot(figsize=(20,10),title='Bitstamp v Coinbase Prices January 4th 2018', color='orange')

coinbase_sliced.loc["2018-01-04":"2018-01-4"].plot(color='blue',ax=ax)

ax.legend(["Bitstamp","Coinbase"])

# %%
# Calculate the arbitrage spread from the January 4th data sample 
arbitrage_spread_early = coinbase_sliced.loc["2018-01-04":"2018-01-4"] - bitstamp_sliced.loc["2018-01-04":"2018-01-4"]

# Generate summary statistics the sample
arbitrage_spread_early.describe()
# Out:
# count    1440.00000
# mean       28.73225
# std        50.00892
# min      -159.12000
# 25%        -6.50500
# 50%        29.64500
# 75%        59.96750
# max       240.00000
# Name: Close, dtype: float64

# %%
# Generate a boxplot to visualize the arbitrage spread of the January 4th data sample
arbitrage_spread_early.plot(kind='box', title='Arbitrage Spread - Early Date')
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Early Date'}>

# %%
# Generate a visualization to illustate Coinbase and Bitstamp prices over the course of one day (February 24th) within the same figure
ax = bitstamp_sliced.loc["2018-02-24":"2018-02-24"].plot(figsize=(20,10),title='Bitstamp v Coinbase Prices February 24th 2018', color='orange')

coinbase_sliced.loc["2018-02-24":"2018-02-24"].plot(color='blue',ax=ax)

ax.legend(["Bitstamp","Coinbase"])

# %%
# Calculate the arbitrage spread from the February 24th data sample 
arbitrage_spread_middle = coinbase_sliced.loc["2018-02-24":"2018-02-24"] - bitstamp_sliced.loc["2018-02-24":"2018-02-24"]

# Generate summary statistics 
arbitrage_spread_middle.describe()
# Out:
# count    1437.000000
# mean        3.396131
# std        22.969472
# min       -50.180000
# 25%       -10.590000
# 50%        -0.010000
# 75%        12.120000
# max       121.320000
# Name: Close, dtype: float64

# %%
# Generate a boxplot to visualize the arbitrage spread of the February 24th data sample
arbitrage_spread_middle.plot(kind='box', title='Arbitrage Spread - Middle Date')
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Middle Date'}>

# %%
# Generate a visualization to illustate Coinbase and Bitstamp prices over the course of one day (March 26th) within the same figure
ax = bitstamp_sliced.loc["2018-03-26":"2018-03-26"].plot(figsize=(20,10),title='Bitstamp v Coinbase Prices March 26th 2018', color='orange')

coinbase_sliced.loc["2018-03-26":"2018-03-26"].plot(color='blue',ax=ax)

ax.legend(["Bitstamp","Coinbase"])

# %%
# Calculate the arbitrage spread from the March 26th data sample 
arbitrage_spread_late = coinbase_sliced.loc["2018-03-26":"2018-03-26"] - bitstamp_sliced.loc["2018-03-26":"2018-03-26"]

# Generate summary statistics for the late DataFrame
arbitrage_spread_late.describe()
# Out:
# count    1432.000000
# mean       -0.722193
# std         8.523060
# min       -32.040000
# 25%        -6.812500
# 50%        -0.730000
# 75%         4.965000
# max        35.070000
# Name: Close, dtype: float64

# %%
# Generate a boxplot to visualize the arbitrage spread of the March 26th data sample
arbitrage_spread_late.plot(kind='box', title='Arbitrage Spread - Late Date')
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread - Late Date'}>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
## January 4th dataset
# Calculate the arbitrage spread for the January 4th date
arbitrage_spread_early = coinbase_sliced.loc["2018-01-04"] - bitstamp_sliced.loc["2018-01-04"]

# Filter out all negative values from the dataset to obtain a list of all positive opportunities for arbitrage
arbitrage_spread_early_positive = arbitrage_spread_early[arbitrage_spread_early > 0.00]
display(arbitrage_spread_early_positive.describe())


## February 24th dataset
# Calculate the arbitrage spread for the February 24th date
arbitrage_spread_mid = coinbase_sliced.loc["2018-02-24"] - bitstamp_sliced.loc["2018-02-24"]

# Filter out all negative values from the dataset to obtain a list of all positive opportunities for arbitrage
arbitrage_spread_mid_positive = arbitrage_spread_mid[arbitrage_spread_mid > 0.00]
display(arbitrage_spread_mid_positive.describe())


## March 26th dataset
# Calculate the arbitrage spread for the March 26th date
arbitrage_spread_late = coinbase_sliced.loc["2018-03-26"] - bitstamp_sliced.loc["2018-03-26"]

# Filter out all negative values from the dataset to obtain a list of all positive opportunities for arbitrage
arbitrage_spread_late_positive = arbitrage_spread_late[arbitrage_spread_late > 0.00]
display(arbitrage_spread_late_positive.describe())
# Out:
# count    1024.000000
# mean       52.519609
# std        36.932341
# min         0.010000
# 25%        24.825000
# 50%        46.505000
# 75%        71.810000
# max       240.000000
# Name: Close, dtype: float64
# count    713.000000
# mean      19.880351
# std       20.699851
# min        0.010000
# 25%        5.040000
# 50%       12.330000
# 75%       27.250000
# max      121.320000
# Name: Close, dtype: float64
# count    651.000000
# mean       6.689247
# std        5.240159
# min        0.010000
# 25%        2.835000
# 50%        5.230000
# 75%        9.195000
# max       35.070000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
## January 4th dataset
# Calculate the arbitrage spread returns for the January 4th dataset
spread_return_early = arbitrage_spread_early_positive/bitstamp_sliced.loc["2018-01-04"]

# Review the spread return DataFrame
display(spread_return_early)


## February 24th dataset
# Calculate the arbitrage spread returns for the February 24th dataset
spread_return_mid = arbitrage_spread_mid_positive/bitstamp_sliced.loc["2018-02-24"]

# Review the spread return DataFrame
display(spread_return_mid)


## March 26th dataset
# Calculate the arbitrage spread returns for the March 26th dataset
spread_return_late = arbitrage_spread_late_positive/bitstamp_sliced.loc["2018-03-26"]

# Review the spread return DataFrame
display(spread_return_late)
# Out:
# Timestamp
# 2018-01-04 00:00:00    0.002634
# 2018-01-04 00:01:00    0.002816
# 2018-01-04 00:02:00    0.001670
# 2018-01-04 00:03:00    0.003870
# 2018-01-04 00:04:00    0.006616
#                          ...
# 2018-01-04 23:55:00         NaN
# 2018-01-04 23:56:00         NaN
# 2018-01-04 23:57:00    0.001583
# 2018-01-04 23:58:00         NaN
# 2018-01-04 23:59:00         NaN
# Name: Close, Length: 1440, dtype: float64
# Timestamp
# 2018-02-24 00:00:00   NaN
# 2018-02-24 00:01:00   NaN
# 2018-02-24 00:02:00   NaN
# 2018-02-24 00:03:00   NaN
# 2018-02-24 00:04:00   NaN
#                        ..
# 2018-02-24 23:55:00   NaN
# 2018-02-24 23:56:00   NaN
# 2018-02-24 23:57:00   NaN
# 2018-02-24 23:58:00   NaN
# 2018-02-24 23:59:00   NaN
# Name: Close, Length: 1437, dtype: float64
# Timestamp
# 2018-03-26 00:00:00    0.000738
# 2018-03-26 00:01:00    0.000122
# 2018-03-26 00:02:00    0.000470
# 2018-03-26 00:03:00    0.000576
# 2018-03-26 00:04:00    0.001395
# ...

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
## January 4th dataset
# Filter out all spread returns that do not cover the costs of transaction (1%) to obtain a list of profitable trades from January 4th
profitable_trades_early = spread_return_early[spread_return_early > .01]

# Review the first five profitable trades
display(profitable_trades_early.head())


## February 24th dataset
# Filter out all spread returns that do not cover the costs of transaction (1%) to obtain a list of profitable trades from February 24th
profitable_trades_mid = spread_return_mid[spread_return_mid > .01]

# Review the first five profitable trades
display(profitable_trades_mid.head())


## March 26th dataset
# Filter out all spread returns that do not cover the costs of transaction (1%) to obtain a list of profitable trades from March 26th
profitable_trades_late = spread_return_late[spread_return_late > .01]

# Review the first five profitable trades
display(profitable_trades_late.head())
# Out:
# Timestamp
# 2018-01-04 01:59:00    0.010101
# 2018-01-04 02:10:00    0.011711
# 2018-01-04 02:12:00    0.011509
# 2018-01-04 02:15:00    0.011171
# 2018-01-04 02:19:00    0.013534
# Name: Close, dtype: float64
# Timestamp
# 2018-02-24 08:32:00    0.012726
# 2018-02-24 09:32:00    0.010974
# 2018-02-24 09:39:00    0.010431
# Name: Close, dtype: float64
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
## January 4th dataset
# Generate summary statistics for profitable trades from January 4th
display(profitable_trades_early.describe())


## February 24th dataset
# Generate summary statistics for profitable trades from February 24th
display(profitable_trades_mid.describe())


## March 26th dataset
# Generate summary statistics for profitable trades from March 26th
display(profitable_trades_late.describe())
# Out:
# count    21.000000
# mean      0.012226
# std       0.002038
# min       0.010004
# 25%       0.010639
# 50%       0.011509
# 75%       0.013534
# max       0.016580
# Name: Close, dtype: float64
# count    3.000000
# mean     0.011377
# std      0.001199
# min      0.010431
# 25%      0.010703
# 50%      0.010974
# 75%      0.011850
# max      0.012726
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
## January 4th dataset
# Calculate the potential profits per trade for all profitable trades from January 4th
profit_early = profitable_trades_early * bitstamp_sliced.loc["2018-01-04"]

# Drop any missing values from the dataset and view sample of results
profit_per_trade_early = profit_early.dropna()
display(profit_per_trade_early.head())


## February 24th dataset
# Calculate the potential profits per trade for all profitable trades from February 24th
profit_mid = profitable_trades_mid * bitstamp_sliced.loc["2018-02-24"]

# Drop any missing values from the dataset and view sample of results
profit_per_trade_mid = profit_mid.dropna()
display(profit_per_trade_mid.head())


## March 26th dataset
# Calculate the potential profits per trade for all profitable trades from March 26th
profit_late = profitable_trades_late * bitstamp_sliced.loc["2018-03-26"]

# Drop any missing values from the dataset and view sample of results
profit_per_trade_late = profit_late.dropna()
display(profit_per_trade_late.head())
# Out:
# Timestamp
# 2018-01-04 01:59:00    150.00
# 2018-01-04 02:10:00    173.45
# 2018-01-04 02:12:00    170.49
# 2018-01-04 02:15:00    165.00
# 2018-01-04 02:19:00    199.37
# Name: Close, dtype: float64
# Timestamp
# 2018-02-24 08:32:00    121.32
# 2018-02-24 09:32:00    107.00
# 2018-02-24 09:39:00    101.75
# Name: Close, dtype: float64
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
## January 4th dataset
# Generate summary statistics for January 4th profits per trade
display(profit_per_trade_early.describe())


## February 24th dataset
# Generate summary statistics for February 24th profits per trade
display(profit_per_trade_mid.describe())


## March 26th dataset
# Generate summary statistics for March 26th profits per trade
display(profit_per_trade_late.describe())
# Out:
# count     21.000000
# mean     178.460952
# std       29.150020
# min      146.740000
# 25%      156.000000
# 50%      170.490000
# 75%      199.370000
# max      240.000000
# Name: Close, dtype: float64
# count      3.000000
# mean     110.023333
# std       10.129246
# min      101.750000
# 25%      104.375000
# 50%      107.000000
# 75%      114.160000
# max      121.320000
# Name: Close, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
# EARLY
profit_per_trade_early.plot(title='Early-Date Profits per Trade')
# Out:
# <AxesSubplot:title={'center':'Early-Date Profits per Trade'}, xlabel='Timestamp'>

# %%
# MID
profit_per_trade_mid.plot(title='Mid-Date Profits per Trade')
# Out:
# <AxesSubplot:title={'center':'Mid-Date Profits per Trade'}, xlabel='Timestamp'>

# %%
# LATE
profit_per_trade_late.plot(title='Late-Date Profits per Trade')
# Out:
# <AxesSubplot:title={'center':'Late-Date Profits per Trade'}, xlabel='Timestamp'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
display(profit_per_trade_early.sum())

display(profit_per_trade_mid.sum())

display(profit_per_trade_late.sum())
# Out:
# 3747.680000000002
# 330.0699999999997
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()

cumulative_profit_mid = profit_per_trade_mid.cumsum()

cumulative_profit_late = profit_per_trade_late.cumsum()

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
cumulative_profit_early.plot(title='Early-Date Cumulative Profits per Trade')
# Out:
# <AxesSubplot:title={'center':'Early-Date Cumulative Profits per Trade'}, xlabel='Timestamp'>

# %%
cumulative_profit_mid.plot(title='Mid-Date Cumulative Profits per Trade')
# Out:
# <AxesSubplot:title={'center':'Mid-Date Cumulative Profits per Trade'}, xlabel='Timestamp'>

# %%
cumulative_profit_late.plot(title='Late-Date Cumulative Profits per Trade')
# Out:
# <AxesSubplot:title={'center':'Late-Date Cumulative Profits per Trade'}, xlabel='Timestamp'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** By digging deeper into the profit details for different time periods, it became evident that as time goes on, opportunities for arbitrage decrease to zero.
#
# The figure Bitstamp v Coinbase Prices January 4th 2018 demonstrates the initial existince of arbitrage opportunity as there is always a gap between the prices of the two exchamges. This analysis is solidified by the Early-Date Cumulative Profits per Trade figure, which highlights non-zero opportunities for profit.
#
# The figure Bitstamp v Coinbase Prices February 24th 2018 demonstrates how these opportunities have decreased over the course of a month as the two lines follow each other almost identically. We can assume that this is due to the fact that individuals are seizing these opportunities for arbitrage and are driving the prices closer together. The data table for this day's profits per trade also shows that there are only 3 opportunities for arbitrage.
#
# The final figure, Bitstamp v Coinbase Prices March 26th 2018 highlights that these opportunities are effectively zero, especially when taking into consideration the cost of these transactions. All opportunities for arbitrage have been exploited and the prices between the two exchanges are nearly identical. All figures and data tables for this date related to profits are empty, which corroborates this hypothesis.
